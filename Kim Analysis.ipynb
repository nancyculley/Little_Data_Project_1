# %%
#Dependencies 

# %matplotlib inline

# Dependencies and Setup
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Load Hurricane Data
hurricanes = "resources/Hurricane_data_all.csv"

# Read the Hurricane CSV files
hurricanes = pd.read_csv(hurricanes)
# Load Index data
sp1500 = "resources/S&P1500_Sector_All.csv"
comm_services = "resources/Communication_Services.csv"
cons_discrete = "resources/Consumer_Discretionary.csv"
cons_staple = "resources/Consumer_Staples.csv"
energy = "resources/Energy.csv"
fin = "resources/Financials.csv"
hlth_care = "resources/Health_Care.csv"
i_t = "resources/Info_Technology.csv"
materials = "resources/Materials.csv"
real_estate = "resources/Real_Estate.csv"
industrial = "resources/Industrials.csv"
utilities = "resources/Utilities.csv"

# Read the Index CSV files
sp1500 = pd.read_csv(sp1500)
comm_services = pd.read_csv(comm_services)
cons_discrete = pd.read_csv(cons_discrete)   
cons_staple = pd.read_csv(cons_staple)
energy = pd.read_csv(energy)
fin  = pd.read_csv(fin)
hlth_care  = pd.read_csv(hlth_care)
i_t = pd.read_csv(i_t)
materials = pd.read_csv(materials)
real_estate = pd.read_csv(real_estate)
industrial = pd.read_csv(industrial)
utilities  = pd.read_csv(utilities)

# %%
sp1500.head()
# Out:
#          Date  \
# 0  12/30/2013
# 1  12/31/2013
# 2    1/1/2014
# 3    1/2/2014
# 4    1/3/2014
#
#    (INDEX) S&P Composite 1500 / Consumer Discretionary - SEC - Total Return      \
# 0                                               0.00
# 1                                               0.37
# 2                                               0.37
# 3                                              -0.16
# 4                                              -0.35
#
#    (INDEX) S&P Composite 1500 / Communication Services -SEC - Total Return      \
# 0                                               0.00
# 1                                              -0.08
# 2                                              -0.08
# 3                                              -0.68
# 4                                              -1.31
#
#    (INDEX) S&P Composite 1500 / Consumer Staples - SEC - Total Return      \
# 0                                               0.00
# 1                                              -0.03
# 2                                              -0.03
# 3                                              -1.12
# 4                                              -1.27
#
#    (INDEX) S&P Composite 1500 / Energy - SEC - Total Return      \
# 0                                               0.00
# 1                                               0.92
# 2                                               0.92
# 3                                              -0.44
# 4                                              -0.69
#
#    (INDEX) S&P Composite 1500 / Financials - SEC - Total Return      \
# 0                                               0.00
# 1                                               0.34
# 2                                               0.34
# 3                                              -0.23
# 4                                               0.39
#
#    (INDEX) S&P Composite 1500 / Health Care - SEC - Total Return      \
# 0                                               0.00
# 1                                               0.00
# 2                                               0.00
# 3                                              -0.58
# 4                                              -0.35
#
#    (INDEX) S&P Composite 1500 / Industrials - SEC - Total Return      \
# 0                                               0.00
# 1                                               0.43
# 2                                               0.43
# 3                                              -0.87
# 4                                              -0.55
#
#    (INDEX) S&P Composite 1500 / Information Technology - SEC - Total Return      \
# 0                                               0.00
# 1                                               0.71
# 2                                               0.71
# 3                                              -0.36
# 4                                              -0.71
#
#    (INDEX) S&P Composite 1500 / Materials - SEC - Total Return      \
# 0                                               0.00
# 1                                               0.26
# 2                                               0.26
# 3                                              -0.48
# 4                                              -0.58
#
#    (INDEX) S&P Composite 1500 Real Estate - SEC - Total Return      \
# 0                                               0.00
# 1                                              -0.49
# 2                                              -0.49
# 3                                              -0.66
# 4                                               0.02
#
#    (INDEX) S&P Composite 1500 / Utilities - SEC - Total Return
# 0                                               0.00
# 1                                               0.23
# 2                                               0.23
# 3                                              -1.34
# 4                                              -1.57

# %%
#Re-set columns 
sp1500['Date'] = pd.to_datetime(sp1500['Date'])
sp1500_2016 = sp1500[(sp1500['Date'] >= '6/1/2016') & (sp1500['Date'] <= '11/30/2016')]
sp1500_2016 = sp1500_2016.reset_index(drop=True)


#Rename headers 
sp1500_2016.columns = ['Date', 'Consumer_Discretionary', 'Communication_Services', 'Consumer_Staples', 
                      'Energy', 'Financials', 'Health_Care', 'Industrials', 'Information_Technology',
                      'Materials', 'Real_Estate', 'Utilities']
sp1500_2016.head()
# Out:
#         Date  Consumer_Discretionary  Communication_Services  \
# 0 2016-06-01                   20.91                   20.33
# 1 2016-06-02                   21.62                   20.95
# 2 2016-06-03                   20.92                   21.63
# 3 2016-06-06                   21.10                   21.60
# 4 2016-06-07                   21.34                   23.40
#
#    Consumer_Staples  Energy  Financials  Health_Care  Industrials  \
# 0             31.14  -19.76       16.03        34.00        12.34
# 1             31.38  -20.04       16.26        35.71        12.57
# 2             32.15  -20.27       14.77        35.21        12.45
# 3             32.21  -18.53       15.40        35.99        13.40
# 4             32.17  -16.78       15.11        35.17        13.89
#
#    Information_Technology  Materials  Real_Estate  Utilities
# 0                   29.83       6.22        41.16      40.84
# 1                   29.75       6.68        41.86      40.81
# 2                   29.22       7.52        42.28      43.07
# 3                   29.69       8.61        41.48      42.87
# 4                   29.91       8.77        42.34      42.77

# %%
plt.plot(sp1500_2016['Date'],sp1500_2016['Consumer_Discretionary'], linewidth = 1, color = "blue")
plt.plot(sp1500_2016['Date'],sp1500_2016['Communication_Services'], linewidth = 1)
plt.plot(sp1500_2016['Date'],sp1500_2016['Consumer_Staples'], linewidth = 1)
plt.plot(sp1500_2016['Date'],sp1500_2016['Energy'], linewidth = 1)
plt.plot(sp1500_2016['Date'],sp1500_2016['Financials'], linewidth = 1)
plt.plot(sp1500_2016['Date'],sp1500_2016['Health_Care'], linewidth = 1)
plt.plot(sp1500_2016['Date'],sp1500_2016['Information_Technology'], linewidth = 1)
plt.plot(sp1500_2016['Date'],sp1500_2016['Industrials'], linewidth = 1)
plt.plot(sp1500_2016['Date'],sp1500_2016['Materials'], linewidth = 1)
plt.plot(sp1500_2016['Date'],sp1500_2016['Real_Estate'], linewidth = 1)
plt.plot(sp1500_2016['Date'],sp1500_2016['Utilities'], linewidth = 1)


plt.title("Hurricane Season 2014")
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.rcParams["figure.figsize"] = (15,5)
plt.show()
